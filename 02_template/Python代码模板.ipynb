# %% [markdown]
# ## 数学建模 - Python代码模板\n
# \n
# - 目标：快速搭建“读取数据 → 清洗 → 建模 → 评估 → 可视化 → 导出结果”的工作流\n
# - 使用方式：复制到作业/项目目录后再按需修改\n

# %%
import os
from pathlib import Path\n
\n
import numpy as np\n
import pandas as pd\n
import matplotlib.pyplot as plt\n
\n
plt.rcParams["figure.dpi"] = 120\n
pd.set_option("display.max_columns", 50)\n
pd.set_option("display.width", 120)\n
\n
PROJECT_DIR = Path.cwd()\n
DATA_DIR = PROJECT_DIR / "data"\n
OUTPUT_DIR = PROJECT_DIR / "outputs"\n
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)\n
\n
PROJECT_DIR, DATA_DIR, OUTPUT_DIR\n

# %% [markdown]
# ### 1. 读取数据\n
# \n
# 将数据放到当前项目目录的 `data/` 下（建议：原始数据与清洗数据分开）。\n

# %%
# 示例：CSV\n
# df = pd.read_csv(DATA_DIR / "raw.csv", encoding="utf-8")\n
# df.head()\n

# %% [markdown]
# ### 2. 数据清洗\n
# \n
# 常见：缺失值、异常值、重复、单位/量纲、类别编码、时间字段等。\n

# %%
# df = df.copy()\n
# df = df.drop_duplicates()\n
# df.isna().sum()\n

# %% [markdown]
# ### 3. 特征工程 / 构造指标\n

# %%
# X = ...\n
# y = ...\n

# %% [markdown]
# ### 4. 建模与求解\n
# \n
# 按题目选择：回归/分类、规划、图论、聚类、时间序列、仿真、优化等。\n

# %%
# 在这里放模型代码\n
# result = ...\n

# %% [markdown]
# ### 5. 结果评估与可视化\n

# %%
# plt.figure()\n
# plt.plot(...)\n
# plt.title("...")\n
# plt.tight_layout()\n
# plt.show()\n

# %% [markdown]
# ### 6. 导出结果\n
# \n
# 建议将关键结果导出到 `outputs/`，并保留生成脚本/参数。\n

# %%
# 示例：导出CSV\n
# out = pd.DataFrame({"a": [1, 2], "b": [3, 4]})\n
# out.to_csv(OUTPUT_DIR / "result.csv", index=False, encoding="utf-8-sig")\n
# (OUTPUT_DIR / "result.csv").resolve()\n

# %% [markdown]
# ### 环境准备

# %%
# 数据处理和科学计算库
import numpy as np
import pandas as pd

# 可视化库
import matplotlib.pyplot as plt
import seaborn as sns

# 机器学习库
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared, r2_score, mean_absolute_error

# 统计分析库
import statsmodels.api as sm
from scipy import stats

# 设置可视化风格
sns.set_style('whitegrid')
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
